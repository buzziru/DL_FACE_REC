# %% [markdown]
# # 불균형 데이터 처리 - 소수 클래스 제거
# - disgusted 클래스 제거
# - batch_size: 64 -> 128로 증가
# - epoch: 60 -> 180

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -qq '/content/drive/MyDrive/team_project(DL)/DATA/emotion.zip' -d '/content/drive/MyDrive/team_project(DL)/DATA/emotion_remove'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from tensorflow.keras.applications import VGG16, InceptionResNetV2
from keras import regularizers
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from PIL import Image

# %%
train_dir = "/content/drive/MyDrive/team_project(DL)/DATA/emotion_remove/train" #passing the path with training images
test_dir = "/content/drive/MyDrive/team_project(DL)/DATA/emotion_remove/test"   #passing the path with testing images

# %%
img_size = 48 #original size of the image

# %%
# 이미지 조회 함수
def plot_images(img_dir, top=10):
    all_img_dirs = os.listdir(img_dir)
    img_files = [os.path.join(img_dir, file) for file in all_img_dirs][:5]
    plt.figure(figsize=(10, 10))
    for idx, img_path in enumerate(img_files):
        plt.subplot(5, 5, idx+1)
        img = plt.imread(img_path)
        plt.tight_layout()
        plt.axis('off')
        plt.imshow(img, cmap='gray')

# %%
plot_images(train_dir+'/angry')

# %%
plot_images(train_dir+'/fearful')

# %%
plot_images(train_dir+'/happy')

# %%
plot_images(train_dir+'/neutral')

# %%
plot_images(train_dir+'/sad')

# %%
plot_images(train_dir+'/surprised')

# %%
# 컬럼 분포 조회 함수
def plot_bar_chart_diagram(path_data):
  dic={}
  for emotion in  os.listdir(path_data):
    dem=0
    for x in os.listdir(path_data+"/"+emotion):
      dem+=1
    dic[emotion]=dem
  print(dic)
  barlist=plt.bar(range(len(dic)), list(dic.values()),tick_label=list(dic.keys()))
#set color
  plt.show()

# %%
# TRAIN 이미지 분포 조회
plot_bar_chart_diagram(train_dir)
# Out:
# {'angry': 3995, 'fearful': 4097, 'happy': 7215, 'neutral': 4965, 'sad': 4830, 'surprised': 3171}

# %%
# TEST 이미지 분포 조회
plot_bar_chart_diagram(test_dir)
# Out:
# {'angry': 958, 'fearful': 1024, 'happy': 1774, 'neutral': 1233, 'sad': 1247, 'surprised': 831}

# %%
# 이미지 전처리(ImageDataGenerator)
# 데이터를 불러오는 동시에 여러가지 전처리를 쉽게 구현해주는 tf.keras 기능
"""
Data Augmentation
--------------------------
rotation_range = rotates the image with the amount of degrees we provide
width_shift_range = shifts the image randomly to the right or left along the width of the image
height_shift range = shifts image randomly to up or below along the height of the image
horizontal_flip = flips the image horizontally
rescale = to scale down the pizel values in our image between 0 and 1
zoom_range = applies random zoom to our object
validation_split = reserves some images to be used for validation purpose
"""

train_datagen = ImageDataGenerator(#rotation_range = 180,  # 이미지 회전
                                         width_shift_range = 0.1,   # 이미지 너비를 따라 오른쪽 혹은 왼쪽으로 무작위 이동
                                         height_shift_range = 0.1,  # 이미지 높이를 따라 위 혹은 아래로 무작위 이동
                                         horizontal_flip = True,    # 이미지 수평으로 뒤집기(가로축 랜덤 설정)
                                         rescale = 1./255,          # 이미지의 픽셀값을 0에서 1사이로 축
                                        #  #zoom_range = 0.2,         # 무작위로 축소/확대 적용
                                        #  validation_split = 0.2     # 유효성 검사를 목적으로 사용할 일부 이미지 예약
                                        )
validation_datagen = ImageDataGenerator(rescale = 1./255,           # validation에도 이미지 전처리 적용
                                        #  validation_split = 0.2
                                        )

# %%
"""
이미지를 불러올 때 이미지 증대 적용
Applying data augmentation to the images as we read
them from their respectivve directories
"""
train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = (img_size,img_size),
                                                    batch_size = 128, # 기존 64에서 128로 증가
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical",
                                                #     subset = "training"  # ImageDataGenerator에 validation_split이 설정된 경우 데이터의 부분집합 ("training" or "validation").
                                                   )
validation_generator = validation_datagen.flow_from_directory(directory = test_dir,
                                                              target_size = (img_size,img_size),
                                                              batch_size = 128, # 기존 64에서 128로 증가
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical",
                                                            #   subset = "validation"   # ImageDataGenerator에 validation_split이 설정된 경우 데이터의 부분집합 ("training" or "validation").
                                                             )
# Out:
# Found 28273 images belonging to 6 classes.
# Found 7067 images belonging to 6 classes.

# %% [markdown]
# ### batch_size
# - 일반적으로 32, 64 크기의 mini-batch가 성능에는 가장 좋다고 알려져 있음
# - batch size를 줄임으로써 얻는 장점: 필요한 메모리 감소
# - batch size를 늘림으로써 얻는 장점: 학습이 안정적

# %%
"""
Modeling


model = Sequential()
model.add(Conv2D(filters = 64,kernel_size = (3,3),padding = 'same',activation = 'relu',input_shape=(img_size,img_size,1)))
model.add(MaxPool2D(pool_size = 2,strides = 2))
model.add(BatchNormalization())

model.add(Conv2D(filters = 128,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(MaxPool2D(pool_size = 2,strides = 2))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(filters = 128,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(MaxPool2D(pool_size = 2,strides = 2))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(filters = 256,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(MaxPool2D(pool_size = 2,strides = 2))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(units = 128,activation = 'relu',kernel_initializer='he_normal'))
model.add(Dropout(0.25))
model.add(Dense(units = 64,activation = 'relu',kernel_initializer='he_normal'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(units = 32,activation = 'relu',kernel_initializer='he_normal'))
model.add(Dense(7,activation = 'softmax'))

"""
# Out:
# "\nModeling\n\n\nmodel = Sequential()\nmodel.add(Conv2D(filters = 64,kernel_size = (3,3),padding = 'same',activation = 'relu',input_shape=(img_size,img_size,1)))\nmodel.add(MaxPool2D(pool_size = 2,strides = 2))\nmodel.add(BatchNormalization())\n\nmodel.add(Conv2D(filters = 128,kernel_size = (3,3),padding = 'same',activation = 'relu'))\nmodel.add(MaxPool2D(pool_size = 2,strides = 2))\nmodel.add(BatchNormalization())\nmodel.add(Dropout(0.25))\n\nmodel.add(Conv2D(filters = 128,kernel_size = (3,3),padding = 'same',activation = 'relu'))\nmodel.add(MaxPool2D(pool_size = 2,strides = 2))\nmodel.add(BatchNormalization())\nmodel.add(Dropout(0.25))\n\nmodel.add(Conv2D(filters = 256,kernel_size = (3,3),padding = 'same',activation = 'relu'))\nmodel.add(MaxPool2D(pool_size = 2,strides = 2))\nmodel.add(BatchNormalization())\n\nmodel.add(Flatten())\nmodel.add(Dense(units = 128,activation = 'relu',kernel_initializer='he_normal'))\nmodel.add(Dropout(0.25))\nmodel.add(Dense(units = 64,activation = 'relu',kernel_initializer='he_normal'))\nmodel.add(BatchNormalization())\nmodel.add(Dropout(0.25))\nmodel.add(Dense(units = 32,activation = 'relu',kernel_initializer='he_normal'))\nmodel.add(Dense(7,activation = 'softmax'))\n\n"

# %%
model= tf.keras.models.Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(48, 48,1)))
model.add(Conv2D(64,(3,3), padding='same', activation='relu' ))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(5,5), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(6, activation='softmax'))  # 클래스 수 변경: 7 -> 6

model.compile(
    optimizer = Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )

# %%
epochs = 180      # 60 -> 180
batch_size = 128  # 64 -> 128

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       204928
#
#  batch_normalization_1 (Bat  (None, 24, 24, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 512)       590336
#
#  batch_normalization_2 (Bat  (None, 12, 12, 512)       2048
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 512)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  batch_normalization_3 (Bat  (None, 6, 6, 512)         2048
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 3, 3, 512)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 4496390 (17.15 MB)
# Trainable params: 4492422 (17.14 MB)
# Non-trainable params: 3968 (15.50 KB)
# _________________________________________________________________

# %%
# 이전 학습이 중단된 지점부터 다시 시작할 수 있도록 현재 에포크를 저장하는 함수
def save_current_epoch(epoch):
    with open('current_epoch.txt', 'w') as f:
        f.write(str(epoch))

# 저장된 현재 에포크를 불러오는 함수
def load_current_epoch():
    try:
        with open('current_epoch.txt', 'r') as f:
            current_epoch = int(f.read().strip())
    except FileNotFoundError:
        current_epoch = 0
    return current_epoch

# %%
# 3가지 콜백(callback) 설정
lrd = ReduceLROnPlateau(monitor='val_accuracy', patience=20, verbose=1, factor=0.5, min_lr=1e-10)  # patience 체크
es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=8)
mc = ModelCheckpoint('/content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
# %%time
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[lrd, es, mc]
)
# Out:
# Epoch 1/180
# 220/220 [==============================] - ETA: 0s - loss: 9.2069 - accuracy: 0.2082
# Epoch 1: val_accuracy improved from -inf to 0.25142, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 220/220 [==============================] - 27092s 123s/step - loss: 9.2069 - accuracy: 0.2082 - val_loss: 8.5754 - val_accuracy: 0.2514 - lr: 1.0000e-04
# Epoch 2/180
# 220/220 [==============================] - ETA: 0s - loss: 8.3407 - accuracy: 0.2374
# Epoch 2: val_accuracy did not improve from 0.25142
# 220/220 [==============================] - 119s 542ms/step - loss: 8.3407 - accuracy: 0.2374 - val_loss: 7.8413 - val_accuracy: 0.2085 - lr: 1.0000e-04
# Epoch 3/180
# 220/220 [==============================] - ETA: 0s - loss: 7.5523 - accuracy: 0.2537
# Epoch 3: val_accuracy improved from 0.25142 to 0.27798, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 120s 547ms/step - loss: 7.5523 - accuracy: 0.2537 - val_loss: 7.1237 - val_accuracy: 0.2780 - lr: 1.0000e-04
# Epoch 4/180
# 220/220 [==============================] - ETA: 0s - loss: 6.7493 - accuracy: 0.2825
# Epoch 4: val_accuracy improved from 0.27798 to 0.32855, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 120s 545ms/step - loss: 6.7493 - accuracy: 0.2825 - val_loss: 6.2070 - val_accuracy: 0.3286 - lr: 1.0000e-04
# Epoch 5/180
# 220/220 [==============================] - ETA: 0s - loss: 6.0047 - accuracy: 0.3057
# Epoch 5: val_accuracy improved from 0.32855 to 0.34957, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 120s 543ms/step - loss: 6.0047 - accuracy: 0.3057 - val_loss: 5.5170 - val_accuracy: 0.3496 - lr: 1.0000e-04
# Epoch 6/180
# 220/220 [==============================] - ETA: 0s - loss: 5.3045 - accuracy: 0.3334
# Epoch 6: val_accuracy improved from 0.34957 to 0.37401, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 140s 638ms/step - loss: 5.3045 - accuracy: 0.3334 - val_loss: 4.9004 - val_accuracy: 0.3740 - lr: 1.0000e-04
# Epoch 7/180
# 220/220 [==============================] - ETA: 0s - loss: 4.7024 - accuracy: 0.3588
# Epoch 7: val_accuracy improved from 0.37401 to 0.40469, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 121s 549ms/step - loss: 4.7024 - accuracy: 0.3588 - val_loss: 4.3874 - val_accuracy: 0.4047 - lr: 1.0000e-04
# Epoch 8/180
# 220/220 [==============================] - ETA: 0s - loss: 4.1675 - accuracy: 0.3821
# Epoch 8: val_accuracy did not improve from 0.40469
# 220/220 [==============================] - 5655s 26s/step - loss: 4.1675 - accuracy: 0.3821 - val_loss: 4.1408 - val_accuracy: 0.3797 - lr: 1.0000e-04
# Epoch 9/180
# 220/220 [==============================] - ETA: 0s - loss: 3.7079 - accuracy: 0.4028
# Epoch 9: val_accuracy improved from 0.40469 to 0.44915, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 120s 544ms/step - loss: 3.7079 - accuracy: 0.4028 - val_loss: 3.3942 - val_accuracy: 0.4491 - lr: 1.0000e-04
# Epoch 10/180
# 220/220 [==============================] - ETA: 0s - loss: 3.3224 - accuracy: 0.4233
# Epoch 10: val_accuracy improved from 0.44915 to 0.47557, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 539ms/step - loss: 3.3224 - accuracy: 0.4233 - val_loss: 3.0545 - val_accuracy: 0.4756 - lr: 1.0000e-04
# Epoch 11/180
# 220/220 [==============================] - ETA: 0s - loss: 2.9944 - accuracy: 0.4464
# Epoch 11: val_accuracy improved from 0.47557 to 0.49148, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 119s 540ms/step - loss: 2.9944 - accuracy: 0.4464 - val_loss: 2.7865 - val_accuracy: 0.4915 - lr: 1.0000e-04
# Epoch 12/180
# 220/220 [==============================] - ETA: 0s - loss: 2.7190 - accuracy: 0.4605
# Epoch 12: val_accuracy improved from 0.49148 to 0.51392, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 536ms/step - loss: 2.7190 - accuracy: 0.4605 - val_loss: 2.4965 - val_accuracy: 0.5139 - lr: 1.0000e-04
# Epoch 13/180
# 220/220 [==============================] - ETA: 0s - loss: 2.4826 - accuracy: 0.4846
# Epoch 13: val_accuracy did not improve from 0.51392
# 220/220 [==============================] - 116s 526ms/step - loss: 2.4826 - accuracy: 0.4846 - val_loss: 2.3412 - val_accuracy: 0.5067 - lr: 1.0000e-04
# Epoch 14/180
# 220/220 [==============================] - ETA: 0s - loss: 2.2945 - accuracy: 0.4990
# Epoch 14: val_accuracy improved from 0.51392 to 0.53182, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 537ms/step - loss: 2.2945 - accuracy: 0.4990 - val_loss: 2.1715 - val_accuracy: 0.5318 - lr: 1.0000e-04
# Epoch 15/180
# 220/220 [==============================] - ETA: 0s - loss: 2.1232 - accuracy: 0.5117
# Epoch 15: val_accuracy improved from 0.53182 to 0.55156, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 534ms/step - loss: 2.1232 - accuracy: 0.5117 - val_loss: 1.9783 - val_accuracy: 0.5516 - lr: 1.0000e-04
# Epoch 16/180
# 220/220 [==============================] - ETA: 0s - loss: 1.9979 - accuracy: 0.5227
# Epoch 16: val_accuracy improved from 0.55156 to 0.56009, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 535ms/step - loss: 1.9979 - accuracy: 0.5227 - val_loss: 1.8731 - val_accuracy: 0.5601 - lr: 1.0000e-04
# Epoch 17/180
# 220/220 [==============================] - ETA: 0s - loss: 1.8886 - accuracy: 0.5313
# Epoch 17: val_accuracy improved from 0.56009 to 0.56591, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 117s 529ms/step - loss: 1.8886 - accuracy: 0.5313 - val_loss: 1.7541 - val_accuracy: 0.5659 - lr: 1.0000e-04
# Epoch 18/180
# 220/220 [==============================] - ETA: 0s - loss: 1.7866 - accuracy: 0.5416
# Epoch 18: val_accuracy did not improve from 0.56591
# 220/220 [==============================] - 117s 532ms/step - loss: 1.7866 - accuracy: 0.5416 - val_loss: 1.7437 - val_accuracy: 0.5595 - lr: 1.0000e-04
# Epoch 19/180
# 220/220 [==============================] - ETA: 0s - loss: 1.7109 - accuracy: 0.5530
# Epoch 19: val_accuracy improved from 0.56591 to 0.59119, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 536ms/step - loss: 1.7109 - accuracy: 0.5530 - val_loss: 1.5874 - val_accuracy: 0.5912 - lr: 1.0000e-04
# Epoch 20/180
# 220/220 [==============================] - ETA: 0s - loss: 1.6401 - accuracy: 0.5593
# Epoch 20: val_accuracy improved from 0.59119 to 0.60412, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 537ms/step - loss: 1.6401 - accuracy: 0.5593 - val_loss: 1.5227 - val_accuracy: 0.6041 - lr: 1.0000e-04
# Epoch 21/180
# 220/220 [==============================] - ETA: 0s - loss: 1.5849 - accuracy: 0.5699
# Epoch 21: val_accuracy did not improve from 0.60412
# 220/220 [==============================] - 116s 526ms/step - loss: 1.5849 - accuracy: 0.5699 - val_loss: 1.5126 - val_accuracy: 0.5940 - lr: 1.0000e-04
# Epoch 22/180
# 220/220 [==============================] - ETA: 0s - loss: 1.5381 - accuracy: 0.5771
# Epoch 22: val_accuracy improved from 0.60412 to 0.60895, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 535ms/step - loss: 1.5381 - accuracy: 0.5771 - val_loss: 1.4578 - val_accuracy: 0.6089 - lr: 1.0000e-04
# Epoch 23/180
# 220/220 [==============================] - ETA: 0s - loss: 1.4969 - accuracy: 0.5830
# Epoch 23: val_accuracy did not improve from 0.60895
# 220/220 [==============================] - 116s 527ms/step - loss: 1.4969 - accuracy: 0.5830 - val_loss: 1.5101 - val_accuracy: 0.5882 - lr: 1.0000e-04
# Epoch 24/180
# 220/220 [==============================] - ETA: 0s - loss: 1.4585 - accuracy: 0.5883
# Epoch 24: val_accuracy improved from 0.60895 to 0.61165, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 536ms/step - loss: 1.4585 - accuracy: 0.5883 - val_loss: 1.4012 - val_accuracy: 0.6116 - lr: 1.0000e-04
# Epoch 25/180
# 220/220 [==============================] - ETA: 0s - loss: 1.4290 - accuracy: 0.5981
# Epoch 25: val_accuracy improved from 0.61165 to 0.61974, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 536ms/step - loss: 1.4290 - accuracy: 0.5981 - val_loss: 1.3725 - val_accuracy: 0.6197 - lr: 1.0000e-04
# Epoch 26/180
# 220/220 [==============================] - ETA: 0s - loss: 1.4091 - accuracy: 0.5985
# Epoch 26: val_accuracy did not improve from 0.61974
# 220/220 [==============================] - 118s 535ms/step - loss: 1.4091 - accuracy: 0.5985 - val_loss: 1.4145 - val_accuracy: 0.5986 - lr: 1.0000e-04
# Epoch 27/180
# 220/220 [==============================] - ETA: 0s - loss: 1.3932 - accuracy: 0.6040
# Epoch 27: val_accuracy improved from 0.61974 to 0.62741, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 119s 540ms/step - loss: 1.3932 - accuracy: 0.6040 - val_loss: 1.3409 - val_accuracy: 0.6274 - lr: 1.0000e-04
# Epoch 28/180
# 220/220 [==============================] - ETA: 0s - loss: 1.3694 - accuracy: 0.6086
# Epoch 28: val_accuracy did not improve from 0.62741
# 220/220 [==============================] - 117s 531ms/step - loss: 1.3694 - accuracy: 0.6086 - val_loss: 1.3595 - val_accuracy: 0.6192 - lr: 1.0000e-04
# Epoch 29/180
# 220/220 [==============================] - ETA: 0s - loss: 1.3600 - accuracy: 0.6106
# Epoch 29: val_accuracy did not improve from 0.62741
# 220/220 [==============================] - 117s 530ms/step - loss: 1.3600 - accuracy: 0.6106 - val_loss: 1.3647 - val_accuracy: 0.6098 - lr: 1.0000e-04
# Epoch 30/180
# 220/220 [==============================] - ETA: 0s - loss: 1.3365 - accuracy: 0.6184
# Epoch 30: val_accuracy improved from 0.62741 to 0.62898, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 116s 529ms/step - loss: 1.3365 - accuracy: 0.6184 - val_loss: 1.3133 - val_accuracy: 0.6290 - lr: 1.0000e-04
# Epoch 31/180
# 220/220 [==============================] - ETA: 0s - loss: 1.3267 - accuracy: 0.6199
# Epoch 31: val_accuracy did not improve from 0.62898
# 220/220 [==============================] - 116s 528ms/step - loss: 1.3267 - accuracy: 0.6199 - val_loss: 1.3317 - val_accuracy: 0.6222 - lr: 1.0000e-04
# Epoch 32/180
# 220/220 [==============================] - ETA: 0s - loss: 1.3176 - accuracy: 0.6243
# Epoch 32: val_accuracy improved from 0.62898 to 0.63139, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 117s 530ms/step - loss: 1.3176 - accuracy: 0.6243 - val_loss: 1.3044 - val_accuracy: 0.6314 - lr: 1.0000e-04
# Epoch 33/180
# 220/220 [==============================] - ETA: 0s - loss: 1.3078 - accuracy: 0.6273
# Epoch 33: val_accuracy improved from 0.63139 to 0.64062, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 117s 534ms/step - loss: 1.3078 - accuracy: 0.6273 - val_loss: 1.2790 - val_accuracy: 0.6406 - lr: 1.0000e-04
# Epoch 34/180
# 220/220 [==============================] - ETA: 0s - loss: 1.3009 - accuracy: 0.6319
# Epoch 34: val_accuracy did not improve from 0.64062
# 220/220 [==============================] - 116s 526ms/step - loss: 1.3009 - accuracy: 0.6319 - val_loss: 1.3791 - val_accuracy: 0.6155 - lr: 1.0000e-04
# Epoch 35/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2963 - accuracy: 0.6328
# Epoch 35: val_accuracy did not improve from 0.64062
# 220/220 [==============================] - 117s 530ms/step - loss: 1.2963 - accuracy: 0.6328 - val_loss: 1.3472 - val_accuracy: 0.6203 - lr: 1.0000e-04
# Epoch 36/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2792 - accuracy: 0.6378
# Epoch 36: val_accuracy did not improve from 0.64062
# 220/220 [==============================] - 117s 531ms/step - loss: 1.2792 - accuracy: 0.6378 - val_loss: 1.3129 - val_accuracy: 0.6288 - lr: 1.0000e-04
# Epoch 37/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2759 - accuracy: 0.6417
# Epoch 37: val_accuracy did not improve from 0.64062
# 220/220 [==============================] - 116s 527ms/step - loss: 1.2759 - accuracy: 0.6417 - val_loss: 1.3102 - val_accuracy: 0.6298 - lr: 1.0000e-04
# Epoch 38/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2702 - accuracy: 0.6439
# Epoch 38: val_accuracy did not improve from 0.64062
# 220/220 [==============================] - 118s 538ms/step - loss: 1.2702 - accuracy: 0.6439 - val_loss: 1.3090 - val_accuracy: 0.6297 - lr: 1.0000e-04
# Epoch 39/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2636 - accuracy: 0.6448
# Epoch 39: val_accuracy improved from 0.64062 to 0.64190, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 117s 534ms/step - loss: 1.2636 - accuracy: 0.6448 - val_loss: 1.2909 - val_accuracy: 0.6419 - lr: 1.0000e-04
# Epoch 40/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2618 - accuracy: 0.6484
# Epoch 40: val_accuracy did not improve from 0.64190
# 220/220 [==============================] - 117s 532ms/step - loss: 1.2618 - accuracy: 0.6484 - val_loss: 1.2875 - val_accuracy: 0.6406 - lr: 1.0000e-04
# Epoch 41/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2510 - accuracy: 0.6498
# Epoch 41: val_accuracy did not improve from 0.64190
# 220/220 [==============================] - 116s 529ms/step - loss: 1.2510 - accuracy: 0.6498 - val_loss: 1.2888 - val_accuracy: 0.6399 - lr: 1.0000e-04
# Epoch 42/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2503 - accuracy: 0.6512
# Epoch 42: val_accuracy did not improve from 0.64190
# 220/220 [==============================] - 117s 533ms/step - loss: 1.2503 - accuracy: 0.6512 - val_loss: 1.3047 - val_accuracy: 0.6362 - lr: 1.0000e-04
# Epoch 43/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2493 - accuracy: 0.6552
# Epoch 43: val_accuracy improved from 0.64190 to 0.64545, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 119s 542ms/step - loss: 1.2493 - accuracy: 0.6552 - val_loss: 1.2739 - val_accuracy: 0.6455 - lr: 1.0000e-04
# Epoch 44/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2376 - accuracy: 0.6596
# Epoch 44: val_accuracy did not improve from 0.64545
# 220/220 [==============================] - 116s 528ms/step - loss: 1.2376 - accuracy: 0.6596 - val_loss: 1.2822 - val_accuracy: 0.6432 - lr: 1.0000e-04
# Epoch 45/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2391 - accuracy: 0.6592
# Epoch 45: val_accuracy improved from 0.64545 to 0.64886, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 117s 533ms/step - loss: 1.2391 - accuracy: 0.6592 - val_loss: 1.2995 - val_accuracy: 0.6489 - lr: 1.0000e-04
# Epoch 46/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2329 - accuracy: 0.6615
# Epoch 46: val_accuracy did not improve from 0.64886
# 220/220 [==============================] - 116s 526ms/step - loss: 1.2329 - accuracy: 0.6615 - val_loss: 1.3159 - val_accuracy: 0.6334 - lr: 1.0000e-04
# Epoch 47/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2350 - accuracy: 0.6610
# Epoch 47: val_accuracy did not improve from 0.64886
# 220/220 [==============================] - 115s 524ms/step - loss: 1.2350 - accuracy: 0.6610 - val_loss: 1.3594 - val_accuracy: 0.6230 - lr: 1.0000e-04
# Epoch 48/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2312 - accuracy: 0.6641
# Epoch 48: val_accuracy did not improve from 0.64886
# 220/220 [==============================] - 115s 525ms/step - loss: 1.2312 - accuracy: 0.6641 - val_loss: 1.2785 - val_accuracy: 0.6489 - lr: 1.0000e-04
# Epoch 49/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2245 - accuracy: 0.6665
# Epoch 49: val_accuracy did not improve from 0.64886
# 220/220 [==============================] - 117s 534ms/step - loss: 1.2245 - accuracy: 0.6665 - val_loss: 1.3372 - val_accuracy: 0.6355 - lr: 1.0000e-04
# Epoch 50/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2271 - accuracy: 0.6697
# Epoch 50: val_accuracy improved from 0.64886 to 0.65014, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 537ms/step - loss: 1.2271 - accuracy: 0.6697 - val_loss: 1.2948 - val_accuracy: 0.6501 - lr: 1.0000e-04
# Epoch 51/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2241 - accuracy: 0.6712
# Epoch 51: val_accuracy improved from 0.65014 to 0.65256, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 117s 532ms/step - loss: 1.2241 - accuracy: 0.6712 - val_loss: 1.2995 - val_accuracy: 0.6526 - lr: 1.0000e-04
# Epoch 52/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2278 - accuracy: 0.6684
# Epoch 52: val_accuracy did not improve from 0.65256
# 220/220 [==============================] - 116s 529ms/step - loss: 1.2278 - accuracy: 0.6684 - val_loss: 1.2973 - val_accuracy: 0.6517 - lr: 1.0000e-04
# Epoch 53/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2162 - accuracy: 0.6772
# Epoch 53: val_accuracy did not improve from 0.65256
# 220/220 [==============================] - 115s 524ms/step - loss: 1.2162 - accuracy: 0.6772 - val_loss: 1.3169 - val_accuracy: 0.6409 - lr: 1.0000e-04
# Epoch 54/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2182 - accuracy: 0.6761
# Epoch 54: val_accuracy improved from 0.65256 to 0.66264, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 116s 528ms/step - loss: 1.2182 - accuracy: 0.6761 - val_loss: 1.2778 - val_accuracy: 0.6626 - lr: 1.0000e-04
# Epoch 55/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2121 - accuracy: 0.6790
# Epoch 55: val_accuracy did not improve from 0.66264
# 220/220 [==============================] - 115s 525ms/step - loss: 1.2121 - accuracy: 0.6790 - val_loss: 1.2851 - val_accuracy: 0.6597 - lr: 1.0000e-04
# Epoch 56/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2062 - accuracy: 0.6784
# Epoch 56: val_accuracy did not improve from 0.66264
# 220/220 [==============================] - 116s 528ms/step - loss: 1.2062 - accuracy: 0.6784 - val_loss: 1.3250 - val_accuracy: 0.6413 - lr: 1.0000e-04
# Epoch 57/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2169 - accuracy: 0.6782
# Epoch 57: val_accuracy improved from 0.66264 to 0.66520, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 116s 528ms/step - loss: 1.2169 - accuracy: 0.6782 - val_loss: 1.2693 - val_accuracy: 0.6652 - lr: 1.0000e-04
# Epoch 58/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2106 - accuracy: 0.6806
# Epoch 58: val_accuracy did not improve from 0.66520
# 220/220 [==============================] - 115s 524ms/step - loss: 1.2106 - accuracy: 0.6806 - val_loss: 1.2871 - val_accuracy: 0.6598 - lr: 1.0000e-04
# Epoch 59/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2055 - accuracy: 0.6825
# Epoch 59: val_accuracy did not improve from 0.66520
# 220/220 [==============================] - 116s 529ms/step - loss: 1.2055 - accuracy: 0.6825 - val_loss: 1.2779 - val_accuracy: 0.6634 - lr: 1.0000e-04
# Epoch 60/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2051 - accuracy: 0.6851
# Epoch 60: val_accuracy did not improve from 0.66520
# 220/220 [==============================] - 117s 531ms/step - loss: 1.2051 - accuracy: 0.6851 - val_loss: 1.2948 - val_accuracy: 0.6598 - lr: 1.0000e-04
# Epoch 61/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2032 - accuracy: 0.6878
# Epoch 61: val_accuracy did not improve from 0.66520
# 220/220 [==============================] - 116s 527ms/step - loss: 1.2032 - accuracy: 0.6878 - val_loss: 1.2944 - val_accuracy: 0.6628 - lr: 1.0000e-04
# Epoch 62/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2080 - accuracy: 0.6857
# Epoch 62: val_accuracy did not improve from 0.66520
# 220/220 [==============================] - 116s 527ms/step - loss: 1.2080 - accuracy: 0.6857 - val_loss: 1.2751 - val_accuracy: 0.6639 - lr: 1.0000e-04
# Epoch 63/180
# 220/220 [==============================] - ETA: 0s - loss: 1.2004 - accuracy: 0.6902
# Epoch 63: val_accuracy did not improve from 0.66520
# 220/220 [==============================] - 117s 531ms/step - loss: 1.2004 - accuracy: 0.6902 - val_loss: 1.3025 - val_accuracy: 0.6562 - lr: 1.0000e-04
# Epoch 64/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1975 - accuracy: 0.6894
# Epoch 64: val_accuracy improved from 0.66520 to 0.66577, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 118s 537ms/step - loss: 1.1975 - accuracy: 0.6894 - val_loss: 1.2773 - val_accuracy: 0.6658 - lr: 1.0000e-04
# Epoch 65/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1944 - accuracy: 0.6920
# Epoch 65: val_accuracy did not improve from 0.66577
# 220/220 [==============================] - 116s 528ms/step - loss: 1.1944 - accuracy: 0.6920 - val_loss: 1.3222 - val_accuracy: 0.6554 - lr: 1.0000e-04
# Epoch 66/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1897 - accuracy: 0.6914
# Epoch 66: val_accuracy did not improve from 0.66577
# 220/220 [==============================] - 116s 527ms/step - loss: 1.1897 - accuracy: 0.6914 - val_loss: 1.2872 - val_accuracy: 0.6624 - lr: 1.0000e-04
# Epoch 67/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1936 - accuracy: 0.6939
# Epoch 67: val_accuracy improved from 0.66577 to 0.67216, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 117s 533ms/step - loss: 1.1936 - accuracy: 0.6939 - val_loss: 1.2864 - val_accuracy: 0.6722 - lr: 1.0000e-04
# Epoch 68/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1929 - accuracy: 0.6939
# Epoch 68: val_accuracy did not improve from 0.67216
# 220/220 [==============================] - 116s 524ms/step - loss: 1.1929 - accuracy: 0.6939 - val_loss: 1.2826 - val_accuracy: 0.6699 - lr: 1.0000e-04
# Epoch 69/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1931 - accuracy: 0.6943
# Epoch 69: val_accuracy did not improve from 0.67216
# 220/220 [==============================] - 115s 522ms/step - loss: 1.1931 - accuracy: 0.6943 - val_loss: 1.3078 - val_accuracy: 0.6678 - lr: 1.0000e-04
# Epoch 70/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1887 - accuracy: 0.6989
# Epoch 70: val_accuracy did not improve from 0.67216
# 220/220 [==============================] - 114s 517ms/step - loss: 1.1887 - accuracy: 0.6989 - val_loss: 1.3274 - val_accuracy: 0.6551 - lr: 1.0000e-04
# Epoch 71/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1932 - accuracy: 0.6971
# Epoch 71: val_accuracy did not improve from 0.67216
# 220/220 [==============================] - 116s 528ms/step - loss: 1.1932 - accuracy: 0.6971 - val_loss: 1.3038 - val_accuracy: 0.6672 - lr: 1.0000e-04
# Epoch 72/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1889 - accuracy: 0.6995
# Epoch 72: val_accuracy did not improve from 0.67216
# 220/220 [==============================] - 117s 530ms/step - loss: 1.1889 - accuracy: 0.6995 - val_loss: 1.2981 - val_accuracy: 0.6705 - lr: 1.0000e-04
# Epoch 73/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1950 - accuracy: 0.6998
# Epoch 73: val_accuracy did not improve from 0.67216
# 220/220 [==============================] - 116s 525ms/step - loss: 1.1950 - accuracy: 0.6998 - val_loss: 1.3482 - val_accuracy: 0.6574 - lr: 1.0000e-04
# Epoch 74/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1882 - accuracy: 0.7026
# Epoch 74: val_accuracy improved from 0.67216 to 0.67770, saving model to /content/drive/MyDrive/team_project(DL)/final/emotion_model_imbalanceremove_best.h5
# 220/220 [==============================] - 117s 531ms/step - loss: 1.1882 - accuracy: 0.7026 - val_loss: 1.2879 - val_accuracy: 0.6777 - lr: 1.0000e-04
# Epoch 75/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1827 - accuracy: 0.7042
# Epoch 75: val_accuracy did not improve from 0.67770
# 220/220 [==============================] - 114s 519ms/step - loss: 1.1827 - accuracy: 0.7042 - val_loss: 1.3018 - val_accuracy: 0.6690 - lr: 1.0000e-04
# Epoch 76/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1878 - accuracy: 0.7033
# Epoch 76: val_accuracy did not improve from 0.67770
# 220/220 [==============================] - 138s 628ms/step - loss: 1.1878 - accuracy: 0.7033 - val_loss: 1.3074 - val_accuracy: 0.6736 - lr: 1.0000e-04
# Epoch 77/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1818 - accuracy: 0.7038
# Epoch 77: val_accuracy did not improve from 0.67770
# 220/220 [==============================] - 115s 523ms/step - loss: 1.1818 - accuracy: 0.7038 - val_loss: 1.3031 - val_accuracy: 0.6754 - lr: 1.0000e-04
# Epoch 78/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1787 - accuracy: 0.7060
# Epoch 78: val_accuracy did not improve from 0.67770
# 220/220 [==============================] - 114s 516ms/step - loss: 1.1787 - accuracy: 0.7060 - val_loss: 1.2953 - val_accuracy: 0.6732 - lr: 1.0000e-04
# Epoch 79/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1919 - accuracy: 0.7021
# Epoch 79: val_accuracy did not improve from 0.67770
# 220/220 [==============================] - 116s 527ms/step - loss: 1.1919 - accuracy: 0.7021 - val_loss: 1.3158 - val_accuracy: 0.6695 - lr: 1.0000e-04
# Epoch 80/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1776 - accuracy: 0.7079
# Epoch 80: val_accuracy did not improve from 0.67770
# 220/220 [==============================] - 115s 521ms/step - loss: 1.1776 - accuracy: 0.7079 - val_loss: 1.3417 - val_accuracy: 0.6662 - lr: 1.0000e-04
# Epoch 81/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1754 - accuracy: 0.7084
# Epoch 81: val_accuracy did not improve from 0.67770
# 220/220 [==============================] - 116s 525ms/step - loss: 1.1754 - accuracy: 0.7084 - val_loss: 1.3153 - val_accuracy: 0.6614 - lr: 1.0000e-04
# Epoch 82/180
# 220/220 [==============================] - ETA: 0s - loss: 1.1753 - accuracy: 0.7070
# Epoch 82: val_accuracy did not improve from 0.67770
# 220/220 [==============================] - 116s 527ms/step - loss: 1.1753 - accuracy: 0.7070 - val_loss: 1.3401 - val_accuracy: 0.6700 - lr: 1.0000e-04
# Epoch 82: early stopping
# CPU times: user 54min 53s, sys: 7min 3s, total: 1h 1min 57s
# Wall time: 12h 53s

# %%
# # 이전 학습이 중단된 지점부터 다시 시작할 수 있도록 현재 에포크를 불러옴
# current_epoch = load_current_epoch()

# %%
# %%time
# history = model.fit(
#     train_generator,
#     steps_per_epoch=train_generator.samples // batch_size,
#     initial_epoch=current_epoch,  # 현재 에포크로부터 다시 시작
#     epochs=epochs,
#     validation_data=validation_generator,
#     validation_steps=validation_generator.samples // batch_size,
#     callbacks=[lrd, es, mc],  # 콜백 함수 적용
# )

# %%
# 학습이 완료된 후 현재 에포크를 저장함
save_current_epoch(epochs)

# %% [markdown]
# ---
# # 모델 성능 평가

# %%
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
train_loss, train_acc = model.evaluate(train_generator)
test_loss, test_acc   = model.evaluate(validation_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_acc*100, test_acc*100))
# Out:
# 221/221 [==============================] - 108s 489ms/step - loss: 1.0632 - accuracy: 0.7508
# 56/56 [==============================] - 20s 360ms/step - loss: 1.3389 - accuracy: 0.6703
# final train accuracy = 75.08 , validation accuracy = 67.03

# %%
model.save_weights('/content/drive/MyDrive/team_project(DL)/final/emotion_model_removeclass_weights.h5')

# %% [markdown]
# ---
# # 이미지 예측

# %%
label_dict = {0:'Angry',1:'Fear',2:'Happy',3:'Neutral',4:'Sad',5:'Surprise'}

# %% [markdown]
# # happy

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/happy.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/happy.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [0.0044943406, 0.008237711, 0.11577001, 0.5504439, 0.31358463, 0.007469395]
# Neutral

# %% [markdown]
# # fear

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/fear.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/fear.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [0.16354461, 0.45149475, 0.007980622, 0.07764079, 0.21796921, 0.08136997]
# Fear

# %% [markdown]
# # neutral

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/neutral face.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/neutral face.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [0.028023774, 0.026192673, 0.0017649519, 0.8426952, 0.10029408, 0.0010293508]
# Neutral

# %% [markdown]
# # surprise

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/surprise face.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/surprise face.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 46ms/step
# [0.1452444, 0.098409064, 0.006684759, 0.33848134, 0.3936213, 0.017559094]
# Sad

# %% [markdown]
# # angry

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/angry face.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/angry face.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [0.03273579, 0.17382361, 0.029843811, 0.026413053, 0.7301826, 0.0070010475]
# Sad

# %% [markdown]
# # 송강

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/송강.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/송강.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [0.0046478007, 0.03749219, 0.01066051, 0.034810588, 0.91169083, 0.00069803395]
# Sad

# %% [markdown]
# # 유해진

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/유해진.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/유해진.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [0.020733228, 0.0068624266, 0.35998058, 0.47559988, 0.13166665, 0.0051572314]
# Neutral

# %% [markdown]
# # 카리나

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/카리나.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/카리나.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [0.17288774, 0.14090905, 0.5309731, 0.0057674106, 0.114965074, 0.034497667]
# Happy

# %% [markdown]
# # 기타

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/sadness.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/sadness.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [0.003520639, 0.023937682, 0.0041773706, 0.11654231, 0.8502207, 0.0016012802]
# Sad

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/trump.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/trump.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [0.11294272, 0.14608118, 0.2894756, 0.046939105, 0.35750452, 0.047056917]
# Sad

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/행복.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/행복.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 27ms/step
# [0.12822025, 0.046117283, 0.2912469, 0.18133864, 0.3468817, 0.0061952267]
# Sad

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/해피.png", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/해피.png")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 20ms/step
# [0.0072865533, 0.008929673, 0.51728046, 0.2925884, 0.17285806, 0.0010568473]
# Happy

# %%
# 이미지 전처리 후의 이미지를 사용하여 결과 도출
img_preprocessed = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/비.jpg", target_size=(48, 48), color_mode='grayscale')
img_preprocessed = image.img_to_array(img_preprocessed)
img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
img_preprocessed /= 255.0

result = model.predict(img_preprocessed)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])

# 원래의 이미지를 사용하여 시각화
img_original = image.load_img("/content/drive/MyDrive/team_project(DL)/DATA/비.jpg")
plt.imshow(img_original)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 68ms/step
# [0.14298591, 0.26995084, 0.16639549, 0.041963656, 0.31480786, 0.06389628]
# Sad
